# %% [markdown]
# # Tree Data tructure

# %%
class Tree_Node:
    def __init__(self, data):
        self.data = data
        self.children = []
        self.parents = None
    
    
    
    def add_child(self,child):
        self.parents = self
        self.children.append(child)
        
    def level(self):
        level = 0
        p =self.parents
        while p:
            level +=1
            p = p.parents
        return level
        
    def print_tree(self):
        spaces = " " * self.level() * 3
        prefix = spaces + "|___" if self.parents else ""
        print(prefix + self.data)
        if self.children:
            for child in self.children:
                child.print_tree()

        
def tree_structure_name():
    root = Tree_Node("Rizwan")
    CTO = Tree_Node("Tayyba")    
    manage = Tree_Node('Ali')
    manage.add_child("Dawoad")
    manage.add_child("Aliha ")
    HR = Tree_Node("Sana")
    HR.add_child("Asma")
    HR.add_child("Aliha")
    root.add_child(CTO)
    root.add_child(manage)
    root.add_child(HR)
    return root
    
def tree_structure_position():
    root = Tree_Node("CEO")
    cto = Tree_Node("CTO")
        
    manager = Tree_Node('Manager')
    manager.add_child("Cloud Manager")
    manager.add_child("App Manager")
    Hr = Tree_Node("HR Head")
    Hr.add_child("Recruitment manager")
    Hr.add_child("HR manager")     
    root.add_child(cto)
    root.add_child(manager)
    root.add_child(Hr)
    
    return root
    
    
# def tree_structure_both():
#     root = Tree_Node("Rizwan(CEO)")
#     cto = Tree_Node("Tayyba(CTO)")
        
#     manager = Tree_Node('Ali(Manager)')
#     manager.add_child("Dawoad(Cloud Manager)")
#     manager.add_child("Aliha (App Manager)")
#     Hr = Tree_Node("Sana('HR Head')")
#     Hr.add_child("Asma (Recruitment manager)")
#     Hr.add_child("Aliha (HR manager)")   

if __name__ == '__main__':

    root = tree_structure_name()
    root.print_tree()

# %%
class Tree_Node:
    def __init__(self, data):
        self.data = data
        self.children = []
        self.parents = None
    
    
    
    def add_child(self,child):
        self.parents = self
        self.children.append(child)
        
    def get_level(self):
        level = 0
        p =self.parents
        while p:
            level +=1
            p = p.parents
        return level
        
    def print_tree(self, level):
        if self.get_level() > level:
            return
        spaces = ' ' * self.get_level() * 3
        prefix = spaces + "|__" if self.parents else ""
        print(prefix + self.data)
        if self.children:
            for child in self.children:
                child.print_tree(level)
        
def tree_structure_name():
    root = Tree_Node("Rizwan")
    CTO = Tree_Node("Tayyba")    
    manage = Tree_Node('Ali')
    manage.add_child("Dawoad")
    manage.add_child("Aliha ")
    HR = Tree_Node("Sana")
    HR.add_child("Asma")
    HR.add_child("Aliha")
    root.add_child(CTO)
    root.add_child(manage)
    root.add_child(HR)
    return root
    
def tree_structure_position():
    root = Tree_Node("CEO")
    cto = Tree_Node("CTO")
        
    manager = Tree_Node('Manager')
    manager.add_child("Cloud Manager")
    manager.add_child("App Manager")
    Hr = Tree_Node("HR Head")
    Hr.add_child("Recruitment manager")
    Hr.add_child("HR manager")     
    root.add_child(cto)
    root.add_child(manager)
    root.add_child(Hr)
    
    return root
    
    
# def tree_structure_both():
#     root = Tree_Node("Rizwan(CEO)")
#     cto = Tree_Node("Tayyba(CTO)")
        
#     manager = Tree_Node('Ali(Manager)')
#     manager.add_child("Dawoad(Cloud Manager)")
#     manager.add_child("Aliha (App Manager)")
#     Hr = Tree_Node("Sana('HR Head')")
#     Hr.add_child("Asma (Recruitment manager)")
#     Hr.add_child("Aliha (HR manager)")   

if __name__ == '__main__':

    root = tree_structure_name()
    root.print_tree(1)
    pass
